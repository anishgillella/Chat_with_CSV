# %%
# !pip install pandasai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 40.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 65.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ...

# %%
import os
import pandas as pd
from pandasai import Agent

# Sample DataFrame
sales_by_country = pd.DataFrame({
    "country": ["United States", "United Kingdom", "France", "Germany", "Italy", "Spain", "Canada", "Australia", "Japan", "China"],
    "sales": [5000, 3200, 2900, 4100, 2300, 2100, 2500, 2600, 4500, 7000]
})

# By default, unless you choose a different LLM, it will use BambooLLM.
# You can get your free API key signing up at https://pandabi.ai (you can also configure it in your .env file)
os.environ["PANDASAI_API_KEY"] = "YOUR-API-KEY"

agent = Agent(sales_by_country)
agent.chat('Which are the top 5 countries by sales?')
# Out:
#           country  sales
# 9           China   7000
# 0   United States   5000
# 8           Japan   4500
# 3         Germany   4100
# 1  United Kingdom   3200

# %%
happiness = pd.read_csv('/content/World_happiness_report_2019.csv')
agent = Agent(happiness)
agent.chat('Which country has the highest happiness score?')
# Out:
# 'The country with the highest happiness score is Finland.'

# %%
agent.chat(
    "Plot the histogram of countries with top 5 happiness score with same color for each bar",
)
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat("What is the GDP per Capita of Canada?")
# Out:
# 1.365

# %%
agent.chat("Give me the names of 3 countries from the report?")
# Out:
# 'The names of the top 3 countries are: Finland, Denmark, Norway.'

# %%
agent.chat("What are the scores, generosity and perceptions of corrpution of Netherlands, Canada and Austria?")
# Out:
#   Country or region  Score  Generosity  Perceptions of corruption
# 4       Netherlands  7.488       0.322                      0.298
# 8            Canada  7.278       0.285                      0.308
# 9           Austria  7.246       0.244                      0.226

# %%
agent.chat("What is the GDP per capita of Canada?")
